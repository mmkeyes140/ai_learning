# %% [markdown]
# <a href="https://colab.research.google.com/github/mmkeyes140/ai_learning/blob/main/bag_of_words_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the dependencies
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Testing adding a text block.  WHat does it look like?  Can I add a pic? ![10639430_10204854544989607_8155173326181164070_n.jpg](data:image/jpeg;base64,...

# %%
# Initialize the stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Define the sentences.
sentence_1 = "I want to invest for retirement."
sentence_2 = "Should I invest in mutual funds, or should I invest in stocks?"
sentence_3 = "I should schedule an appointment with a financial planner."

# %%
# Tokenize the input text
tokens = []
sentence_1_tokens = nltk.word_tokenize(sentence_1.lower())
tokens.append(sentence_1_tokens)
sentence_2_tokens = nltk.word_tokenize(sentence_2.lower())
tokens.append(sentence_2_tokens)
sentence_3_tokens = nltk.word_tokenize(sentence_3.lower())
tokens.append(sentence_3_tokens)

tokens
# Out:
# [['i', 'want', 'to', 'invest', 'for', 'retirement', '.'],
#  ['should',
#   'i',
#   'invest',
#   'in',
#   'mutual',
#   'funds',
#   ',',
#   'or',
#   'should',
#   'i',
#   'invest',
#   'in',
#   'stocks',
#   '?'],
#  ['i',
#   'should',
#   'schedule',
#   'an',
#   'appointment',
#   'with',
#   'a',
#   'financial',
#   'planner',
#   '.']]

# %%
# Remove stopwords
filtered_tokens = []
for token in tokens:
    filtered_token = [word for word in token if not word in stop_words]
    filtered_tokens.append(filtered_token)

filtered_tokens
# Out:
# [['want', 'invest', 'retirement', '.'],
#  ['invest', 'mutual', 'funds', ',', 'invest', 'stocks', '?'],
#  ['schedule', 'appointment', 'financial', 'planner', '.']]

# %%
# Create the bag-of-words
bag_of_words = {}
for i in range(len(filtered_tokens)):
    for word in filtered_tokens[i]:
        if word not in bag_of_words:
            bag_of_words[word] = 0
        bag_of_words[word] += 1

bag_of_words
# Out:
# {'want': 1,
#  'invest': 3,
#  'retirement': 1,
#  '.': 2,
#  'mutual': 1,
#  'funds': 1,
#  ',': 1,
#  'stocks': 1,
#  '?': 1,
#  'schedule': 1,
#  'appointment': 1,
#  'financial': 1,
#  'planner': 1}
